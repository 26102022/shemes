# %%
import matplotlib.pyplot as plt
import random
import numpy as np
random.random()
# Out:
# 0.5707964701074506

# %%
list1=[]
for i in range(600):
    list1.append(round(random.gauss(17, 5.1),1))

# %%
list2=[]
countu=0
for i in range(600):
    list2.append(round(random.gauss(17, 5.1),1))

# %%
#list1=[0,0,0,1,1]
from collections import Counter

c=Counter(list1)
print(c)
r=c[list(c.keys())[0]]
print(r)
f = ([list(c.keys())[0],list(c.keys())[0]])
plt.plot(f,[0,r])
plt.hist(list2, alpha=0.5)
plt.hist(list1, alpha=0.5)
#plt.hist(element1, alpha=0.8)
# Out:
# Counter({15.3: 11, 21.7: 9, 19.2: 8, 17.5: 8, 16.9: 8, 20.2: 7, 20.4: 7, 17.1: 7, 17.2: 7, 21.8: 7, 21.5: 7, 19.5: 7, 17.7: 7, 22.2: 6, 15.5: 6, 14.6: 6, 16.1: 6, 18.8: 6, 15.1: 6, 19.4: 6, 16.0: 6, 13.7: 6, 17.8: 6, 13.3: 5, 15.6: 5, 19.6: 5, 19.9: 5, 17.3: 5, 16.6: 5, 14.1: 5, 22.5: 5, 13.4: 5, 25.2: 5, 14.2: 5, 23.0: 5, 12.5: 5, 12.7: 5, 20.1: 5, 16.5: 4, 19.3: 4, 18.6: 4, 24.4: 4, 11.9: 4, 17.0: 4, 13.5: 4, 18.4: 4, 15.0: 4, 20.5: 4, 18.2: 4, 12.3: 4, 14.0: 4, 13.1: 4, 13.6: 4, 23.7: 4, 19.1: 4, 19.7: 4, 22.1: 4, 11.4: 4, 20.6: 4, 9.9: 4, 12.8: 4, 21.1: 4, 18.0: 4, 12.9: 4, 22.7: 4, 12.0: 4, 14.4: 4, 19.8: 4, 19.0: 4, 24.1: 3, 15.2: 3, 15.9: 3, 21.3: 3, 16.3: 3, 10.2: 3, 10.0: 3, 20.7: 3, 16.2: 3, 16.4: 3, 6.2: 3, 11.5: 3, 13.9: 3, 21.6: 3, 20.8: 3, 18.3: 3, 25.0: 3, 24.3: 3, 9.8: 3, 22.6: 3, 17.6: 3, 21.2: 3, 14.3: 3, 18.7: 3, 21.0: 3, 11.0: 3, 11.2: 3, 12.6: 3, 17.9: 3, 27.1: 3, 11.8: 3, 14.8: 3, 14.7: 3, 12.4: 3, 11.3: 3, 10.4: 3, 15.4: 3, 16.7: 3, 18.5: 3, 17.4: 3, 26.7: 2, 12.2: 2, 14.5: 2, 28.0: 2, 25.5: 2, 10.5: 2, 15.8: 2, 28.6: 2, 20.3: 2, 23.1: 2, 9.5: 2, 14.9: 2, 23.5: 2, 18.1: 2, 22.8: 2, 23.6: 2, 10.6: 2, 25.4: 2, 7.4: 2, 9.1: 2, 6.4: 2, 4.1: 2, 24.0: 2, 23.2: 2, 18.9: 2, 11.7: 2, 7.5: 2, 22.9: 2, 13.8: 2, 22.0: 2, 21.4: 2, 20.9: 2, 25.9: 2, 9.7: 2, 21.9: 1, 22.4: 1, 26.1: 1, 16.8: 1, 10.1: 1, 8.4: 1, 13.0: 1, 9.6: 1, 6.0: 1, 24.7: 1, 6.9: 1, 24.6: 1, 5.2: 1, 28.4: 1, 8.9: 1, 15.7: 1, 20.0: 1, 7.3: 1, 10.3: 1, 24.9: 1, 29.6: 1, 8.3: 1, 23.8: 1, 8.5: 1, 32.4: 1, 24.8: 1, 25.7: 1, 26.2: 1, 5.0: 1, 2.6: 1, 10.7: 1, 7.7: 1, 27.2: 1, 28.8: 1, 25.8: 1, 7.9: 1, 4.3: 1, 8.2: 1, 6.8: 1, 10.8: 1, 27.5: 1, 31.0: 1, 9.0: 1, 30.1: 1, 22.3: 1, 6.3: 1, 26.9: 1, 12.1: 1, 31.2: 1, 29.3: 1, 23.9: 1, 24.5: 1, 27.8: 1})
# 5
# (array([  6.,  20.,  49., 101., 126., 135.,  97.,  45.,  16.,   5.]),
#  array([ 2.6 ,  5.58,  8.56, 11.54, 14.52, 17.5 , 20.48, 23.46, 26.44,
#         29.42, 32.4 ]),
#  <BarContainer object of 10 artists>)

# %%
c=[]
a=list1
b=list2


for i in a:
    for j in b:
        if i == j:
            c.append(i)
            break
 
print(len(c)/len((a)))
# Out:
# 0.9266666666666666

# %%
c=[]

a=list1
b=list2


for i in a:
    for j in b:
        if i == j:
            c.append(i)
            break
 
print(len(c)/len((a)))
c1=[]
a=list2
b=list1


for i in a:
    for j in b:
        if i == j:
            c1.append(i)
            break
 
print(len(c1)/len((a)))
# Out:
# 0.9266666666666666
# 0.9033333333333333

# %%
wels=[]
wels1=[]
wels2=[]

# %%
for i in range(3):
    wels.append(round(random.gauss(17, 2.1),1))

# %%
for i in range(3):
    wels1.append(round(random.gauss(17, 2.1),1))

# %%
for i in range(3):
    wels2.append(round(random.gauss(17, 2.1),1))

# %%
rows=[wels,wels1,wels2]
print(rows)
fig, ax = plt.subplots()
ax.matshow(rows)
for (i, j), z in np.ndenumerate(rows):
    ax.text(j, i, '{:0.1f}'.format(z), ha='center', va='center',
            bbox=dict(boxstyle='round', facecolor='white', edgecolor='0.3'))
plt.show()
# Out:
# [[17.0, 20.4, 14.5], [13.9, 17.9, 17.7], [20.0, 15.4, 15.3]]

# %%
wels=5
rows=3
list1=[0]*wels*rows
for i in range(wels-1):
    list1[i]=(round(random.gauss(42, 2.1),1))
for i in range(rows*wels-wels):
    list1[wels+i]=(round(random.gauss(25, 2.1),1))
print(list1)
# Out:
# [45.0, 44.1, 42.5, 41.0, 0, 28.4, 27.3, 28.0, 23.6, 21.5, 24.9, 25.4, 26.3, 27.6, 26.7]

# %%
(round(random.gauss(42, 2.1),1))
(round(random.gauss(500, 12.1),1))
# Out:
# 511.1

# %%
print((round(random.gauss(42, 2.1),1))+(round(random.gauss(500, 12.1),1)))
# Out:
# 529.2

# %%
wels=5
rows=3
list1=[0]*wels*rows
for i in range(wels-1):
    list1[i]=(round(random.gauss(42, 2.1),1))
for i in range(rows*wels-wels):
    list1[wels+i]=(round(random.gauss(25, 2.1),1))
print(list1)
sum=[0]
mat=[]
maat=[]
for i in range(wels-1):
    sum.append(sum[i]+list1[i])

for i in range(wels):
    sum.append(sum[i]+list1[i+wels])

for i in range(wels):
    sum.append(sum[wels+i]+list1[i+wels*2])
for i in range(3):
    mat=[]
    for j in range(5):
        mat.append(sum[i*wels+j])
    maat.append(mat)
for j in range(rows):
    for i in range(wels):
        maat[j][i]=float(maat[j][i])+float(round(random.gauss(500, 10.5),1))

mt=[[],[],[]]
mt[0]=maat[2]
mt[1]=maat[1]
mt[2]=maat[0]
fig, ax1 = plt.subplots()
ax1.matshow(mt)
for (i, j), z in np.ndenumerate(mt):
    ax1.text(j, i, '{:0.1f}'.format(z), ha='center', va='center',
            bbox=dict(boxstyle='round', facecolor='white', edgecolor='0.3'))
aa=[]
ss=[]
ss.append(mt[rows-1][0]-mt[rows-1][0])
ss.append(mt[rows-2][0]-mt[rows-1][0])
ss.append(mt[0][0]-mt[rows-2][0])
aa.append(ss)

for i in range(wels-1):
    ss=[]
    ss.append(mt[rows-1][i+1]-mt[rows-1][i])
    ss.append(mt[rows-2][i+1]-mt[rows-1][i+1])
    ss.append(mt[0][i+1]-mt[rows-2][i+1])
    aa.append(ss)


maat=np.transpose(aa)
mt[0]=maat[2]
mt[1]=maat[1]
mt[2]=maat[0]
fig, ax = plt.subplots()
aaaaa=ax.matshow(mt)

for (i, j), z in np.ndenumerate(mt):
    ax.text(j, i, '{:0.1f}'.format(z), ha='center', va='center',
            bbox=dict(boxstyle='round', facecolor='white', edgecolor='0.3'))
plt.show()
# Out:
# [39.2, 39.9, 37.2, 46.5, 0, 26.0, 26.0, 18.9, 28.6, 27.9, 24.2, 26.6, 25.3, 25.3, 22.8]

# %%
mt=[[],[],[]]
print(list1)
mt[2]=list1[:wels]
mt[1]=list1[wels:2*wels]
mt[0]=list1[2*wels:]
mt[2].reverse()

print(mt[0][0])
# Out:
# [39.2, 39.9, 37.2, 46.5, 0, 26.0, 26.0, 18.9, 28.6, 27.9, 24.2, 26.6, 25.3, 25.3, 22.8]
# 24.2

# %%
fig, ax = plt.subplots()
aaaaa=ax.matshow(mt, interpolation="nearest")
fig.colorbar()
for (i, j), z in np.ndenumerate(mt):
    ax.text(j, i, '{:0.1f}'.format(z), ha='center', va='center',
            bbox=dict(boxstyle='round', facecolor='white', edgecolor='0.3'))
plt.show()

# %%
ss=[0]
print(mt)
aa=[]
for i in range(wels-1):
       ss.append(mt[2][i+1]-mt[2][i])
aa.append(ss)
ss=[mt[1][0]]
for i in range(wels-1):
    print(i)
    ss.append(mt[1][i+1]-mt[1][i])
aa.append(ss)
ss=[mt[0][0]-mt[1][0]]
for i in range(wels-1):
    ss.append(mt[0][i+1]-mt[0][i])
aa.append(ss)
mt=aa
fig, ax = plt.subplots()
aaaaa=ax.matshow(mt, interpolation="nearest")
fig.colorbar(aaaaa)
for (i, j), z in np.ndenumerate(mt):
    ax.text(j, i, '{:0.1f}'.format(z), ha='center', va='center',
            bbox=dict(boxstyle='round', facecolor='white', edgecolor='0.3'))
plt.show()
# Out:
# [[24.2, 26.6, 25.3, 25.3, 22.8], [26.0, 26.0, 18.9, 28.6, 27.9], [0, 46.5, 37.2, 39.9, 39.2]]
# 0
# 1
# 2
# 3

# %% [markdown]
# ![image.png](attachment:image.png)
