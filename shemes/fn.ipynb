# %%
#1 вариант
x10=90
dx1=20
x20=1
dx2=0.1
x30=1.5
dx3=0.4
x40=0.8
dx4=0.3
yy=[73,69,68,58,58.5,64,54,59,52,84,94,92,100,106,109,98,90,97,77,85,78,105,95,100,75,78,72,96,92,94,88,85,88,63,65,67,48,45,47,51,54,54,120,218,117,121,118,115]
#19 вариант
x10=90
dx1=20
x20=1
dx2=0.1
x30=1.5
dx3=0.4
x40=0.8
dx4=0.3
yy=[71	67	65	70	78	69	11	13	14	18	15	17	13	16	18	38	40	68	47	45	48	25	28	22	55	48	50	17	35	38	48	40	47	50	56	58	24	28	26	15	16	12	19	18	22	26	23	24]
